# %% [markdown]
# # My perfect holiday
# In this notebook I will introduce someone and her/his **holiday preferences** with a *picture* and a *link to a youtube video* of this holiday preference. <br>
# I am goint to continue by choosing a <span style="color:blue">name</span> for the person:

# %%
p_name = input("Person's name: ") # Lars
p_preferences = input("Holiday preferences: ")
print("Hello. My name is " + p_name + " and my personal holiday preferences are: " + p_preferences)
# Out:
# Person's name:  Lars
# Holiday preferences:  Swimming, Reading
# Hello. My name is Lars and my personal holiday preferences are: Swimming, Reading

# %% [markdown]
# Now that we now, how the person is called and what the person likes, let's have a look at him/her:
# ![alt text](lf.jpg)

# %% [markdown]
# ### The favorite place:
#
# This persons favorite place to visit - Luxembourg.
#
# ![alt text](lx.jpg)
#
# What activities the person likes in Lux:
# - Take big walks through the nearby forrests with the dogs.
# - Cook together
# - SLEEP!

# %% [markdown]
# Last but not least, let's have a look at this beautiful place full of hobbit-like landscapes and achitecture:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('cJoxdtgZjQw', width=800, height=500)
# "https://www.youtube.com/watch?v=cJoxdtgZjQw" is the source of the video.
